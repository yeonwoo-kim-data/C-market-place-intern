# %%
# !pip install numpy pandas matplotlib seaborn
# !pip install scikit-learn
# !pip install jinja2
# !pip install sentence-transformers hdbscan
# Out:
# Requirement already satisfied: numpy in ./intern/lib/python3.9/site-packages (2.0.2)
# Requirement already satisfied: pandas in ./intern/lib/python3.9/site-packages (2.3.2)
# Requirement already satisfied: matplotlib in ./intern/lib/python3.9/site-packages (3.9.4)
# Requirement already satisfied: seaborn in ./intern/lib/python3.9/site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./intern/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./intern/lib/python3.9/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./intern/lib/python3.9/site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./intern/lib/python3.9/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in ./intern/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./intern/lib/python3.9/site-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./intern/lib/python3.9/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in ./intern/lib/python3.9/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in ./intern/lib/python3.9/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./intern/lib/python3.9/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./intern/lib/python3.9/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in ./intern/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.0)
# Requirement already satisfied: six>=1.5 in ./intern/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: scikit-learn in ./intern/lib/python3.9/site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in ./intern/lib/python3.9/site-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in ./intern/lib/python3.9/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in ./intern/lib/python3.9/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./intern/lib/python3.9/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: jinja2 in ./intern/lib/python3.9/site-packages (3.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in ./intern/lib/python3.9/site-packages (from jinja2) (3.0.2)
# Requirement already satisfied: sentence-transformers in ./intern/lib/python3.9/site-packages (5.1.0)
# Requirement already satisfied: hdbscan in ./intern/lib/python3.9/site-packages (0.8.40)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in ./intern/lib/python3.9/site-packages (from sentence-transformers) (4.56.0)
# Requirement already satisfied: tqdm in ./intern/lib/python3.9/site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in ./intern/lib/python3.9/site-packages (from sentence-transformers) (2.8.0)
# Requirement already satisfied: scikit-learn in ./intern/lib/python3.9/site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in ./intern/lib/python3.9/site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in ./intern/lib/python3.9/site-packages (from sentence-transformers) (0.34.4)
# Requirement already satisfied: Pillow in ./intern/lib/python3.9/site-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in ./intern/lib/python3.9/site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in ./intern/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.19.1)
# Requirement already satisfied: numpy>=1.17 in ./intern/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in ./intern/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in ./intern/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in ./intern/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.9.1)
# Requirement already satisfied: requests in ./intern/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in ./intern/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.22.0)
# Requirement already satisfied: safetensors>=0.4.3 in ./intern/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in ./intern/lib/python3.9/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.9.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in ./intern/lib/python3.9/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.1.9)
# Requirement already satisfied: joblib>=1.0 in ./intern/lib/python3.9/site-packages (from hdbscan) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./intern/lib/python3.9/site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: sympy>=1.13.3 in ./intern/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx in ./intern/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in ./intern/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./intern/lib/python3.9/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./intern/lib/python3.9/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./intern/lib/python3.9/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in ./intern/lib/python3.9/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./intern/lib/python3.9/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./intern/lib/python3.9/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.8.3)

# %% [markdown]
# # 씨마켓플레이스

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from matplotlib import rcParams
from matplotlib import font_manager as fm

# 폰트 경로 직접 지정
font_path = '/System/Library/Fonts/Supplemental/AppleGothic.ttf'  # Mac 기본 폰트
font_prop = fm.FontProperties(fname=font_path)
# (, fontproperties=font_prop) 직접 추가해야 한글화 
# rcParams에 적용
rcParams['font.family'] = font_prop.get_name()
rcParams['axes.unicode_minus'] = False

# %% [markdown]
# # 데이터 로드

# %%
df = pd.read_csv('/Users/c-market/Downloads/data_list.csv', low_memory=False)

df.columns = df.columns.str.replace(' ', '_')

# %%
df
# Out:
#             NO  ROWNUM totalCount  pdt_cd pdt_share pdt_share_txt send_chk  \
# 0            1  104488     104488  100001         Y            공유        Y
# 1            2  104487     104488  100002         Y            공유        Y
# 2            3  104486     104488  100003         Y            공유        Y
# 3            4  104485     104488  100004         Y            공유        Y
# 4            5  104484     104488  100005         Y            공유        Y
# ...        ...     ...        ...     ...       ...           ...      ...
# 104483  104484       5     104488  204575         Y            공유        Y
# 104484  104485       4     104488  204574         Y            공유        Y
# 104485  104486       3     104488  204585         Y            공유        Y
# 104486  104487       2     104488  204587         Y            공유        Y
# 104487  104488       1     104488  204586         Y            공유        Y
#
#        send_chk_txt pdt_code                             pdt_name  ...  \
# 0              전송완료       SO                      전산기록지(80컬럼/양미싱)  ...
# 1              전송완료       SO                     전산기록지(132컬럼/양미싱)  ...
# 2              전송완료       SO                   팩스용지(15mX210mm/한솔)  ...
# 3              전송완료       SO                   팩스용지(15mX216mm/한솔)  ...
# 4              전송완료       SO                   팩스용지(30mX210mm/한솔)  ...
# ...             ...      ...                                  ...  ...
# 104483         전송완료       SZ                     BKA-001 무릎 보호대 K  ...
# 104484         전송완료       SZ                       BKH-002 손목 보호대  ...
# 104485         전송완료       SZ  [고려에이스] Centrifuge Tube Rack 스텐원심관랙  ...
# 104486         전송완료       SZ                  Bambu 저온용 재사용 가능 스풀  ...
# 104487         전송완료       SZ                        [뱀부랩] PETG HF  ...
#
#        pdt_cas pdt_price  pdt_request_date pdt_simg_type           pdt_simg  \
# 0          NaN     25600           50:34.9             U                NaN
# 1          NaN     36100           50:34.9             U                NaN
# 2          NaN      2100           50:34.9             U                NaN
# 3          NaN      2100           50:34.9             U                NaN
# 4          NaN      3600           50:34.9             U                NaN
# ...        ...       ...               ...           ...                ...
# 104483     NaN         0           25:45.8           NaN  cmarket_empty.png
# 104484     NaN         0           25:45.8           NaN  cmarket_empty.png
# 104485     NaN         0           31:18.6           NaN  cmarket_empty.png
# 104486     NaN         0           52:19.6           NaN  cmarket_empty.png
# 104487     NaN         0           52:19.6           NaN  cmarket_empty.png
#
#        pdt_simg_org pdt_simg_size brand_name dam_name pdt_simg_file_key
# 0               NaN           NaN      오피스디포      윤갑석               NaN
# 1               NaN           NaN      오피스디포      윤갑석               NaN
# 2               NaN           NaN      오피스디포      윤갑석               NaN
# 3               NaN           NaN      오피스디포      윤갑석               NaN
# 4               NaN           NaN      오피스디포      윤갑석               NaN
# ...             ...           ...        ...      ...               ...
# 104483          NaN           NaN        NaN      백제현               NaN
# 104484          NaN           NaN        NaN      백제현               NaN
# 104485          NaN           NaN      고려에이스      박예린               NaN
# 104486          NaN           NaN        뱀부랩      안재용               NaN
# 104487          NaN           NaN        뱀부랩      안재용               NaN
#
# [104488 rows x 21 columns]

# %%
def summary(df):
    summry = pd.DataFrame(df.dtypes, columns=['data type'])
    summry['#missing'] = df.isnull().sum().values
    summry['Duplicate'] = df.duplicated().sum()
    summry['#unique'] = df.nunique().values
    desc = pd.DataFrame(df.describe(include='all').transpose())
    summry['min'] = desc['min'].values
    summry['max'] = desc['max'].values
    summry['avg'] = desc['mean'].values
    summry['std dev'] = desc['std'].values
    summry['top value'] = desc['top'].values
    summry['Freq'] = desc['freq'].values

    return summry

# %%
summary(df).style.set_caption("**Summary of the product Data**").\
background_gradient(cmap='Pastel2_r', axis=0). \
set_properties(**{'border': '1.3px dotted', 'color': '', 'caption-side': 'left'})
# Out:
# <style type="text/css">
# #T_84766_row0_col0, #T_84766_row0_col4, #T_84766_row0_col5, #T_84766_row0_col6, #T_84766_row0_col7, #T_84766_row0_col8, #T_84766_row0_col9, #T_84766_row1_col0, #T_84766_row1_col4, #T_84766_row1_col5, #T_84766_row1_col6, #T_84766_row1_col7, #T_84766_row1_col8, #T_84766_row1_col9, #T_84766_row2_col0, #T_84766_row2_col4, #T_84766_row2_col5, #T_84766_row2_col6, #T_84766_row2_col7, #T_84766_row2_col8, #T_84766_row2_col9, #T_84766_row3_col0, #T_84766_row3_col4, #T_84766_row3_col5, #T_84766_row3_col6, #T_84766_row3_col7, #T_84766_row3_col8, #T_84766_row3_col9, #T_84766_row4_col0, #T_84766_row4_col4, #T_84766_row4_col5, #T_84766_row4_col6, #T_84766_row4_col7, #T_84766_row4_col8, #T_84766_row4_col9, #T_84766_row5_col0, #T_84766_row5_col4, #T_84766_row5_col5, #T_84766_row5_col6, #T_84766_row5_col7, #T_84766_row5_col8, #T_84766_row5_col9, #T_84766_row6_col0, #T_84766_row6_col4, #T_84766_row6_col5, #T_84766_row6_col6, #T_84766_row6_col7, #T_84766_row6_col8, #T_84766_row6_col9, #T_84766_row7_col0, #T_84766_row7_col4, #T_84766_row7_col5, #T_84766_row7_col6, #T_84766_row7_col7, #T_84766_row7_col8, #T_84766_row7_col9, #T_84766_row8_col0, #T_84766_row8_col4, #T_84766_row8_col5, #T_84766_row8_col6, #T_84766_row8_col7, #T_84766_row8_col8, #T_84766_row8_col9, #T_84766_row9_col0, #T_84766_row9_col4, #T_84766_row9_col5, #T_84766_row9_col6, #T_84766_row9_col7, #T_84766_row9_col8, #T_84766_row9_col9, #T_84766_row10_col0, #T_84766_row10_col4, #T_84766_row10_col5, #T_84766_row10_col6, #T_84766_row10_col7, #T_84766_row10_col8, #T_84766_row10_col9, #T_84766_row11_col0, #T_84766_row11_col4, #T_84766_row11_col5, #T_84766_row11_col6, #T_84766_row11_col7, #T_84766_row11_col8, #T_84766_row11_col9, #T_84766_row12_col0, #T_84766_row12_col4, #T_84766_row12_col5, #T_84766_row12_col6, #T_84766_row12_col7, #T_84766_row12_col8, #T_84766_row12_col9, #T_84766_row13_col0, #T_84766_row13_col4, #T_84766_row13_col5, #T_84766_row13_col6, #T_84766_row13_col7, #T_84766_row13_col8, #T_84766_row13_col9, #T_84766_row14_col0, #T_84766_row14_col4, #T_84766_row14_col5, #T_84766_row14_col6, #T_84766_row14_col7, #T_84766_row14_col8, #T_84766_row14_col9, #T_84766_row15_col0, #T_84766_row15_col4, #T_84766_row15_col5, #T_84766_row15_col6, #T_84766_row15_col7, #T_84766_row15_col8, #T_84766_row15_col9, #T_84766_row16_col0, #T_84766_row16_col4, #T_84766_row16_col5, #T_84766_row16_col6, #T_84766_row16_col7, #T_84766_row16_col8, #T_84766_row16_col9, #T_84766_row17_col0, #T_84766_row17_col4, #T_84766_row17_col5, #T_84766_row17_col6, #T_84766_row17_col7, #T_84766_row17_col8, #T_84766_row17_col9, #T_84766_row18_col0, #T_84766_row18_col4, #T_84766_row18_col5, #T_84766_row18_col6, #T_84766_row18_col7, #T_84766_row18_col8, #T_84766_row18_col9, #T_84766_row19_col0, #T_84766_row19_col4, #T_84766_row19_col5, #T_84766_row19_col6, #T_84766_row19_col7, #T_84766_row19_col8, #T_84766_row19_col9, #T_84766_row20_col0, #T_84766_row20_col4, #T_84766_row20_col5, #T_84766_row20_col6, #T_84766_row20_col7, #T_84766_row20_col8, #T_84766_row20_col9 {
#   border: 1.3px dotted;
#   color: ;
#   caption-side: left;
# }
# #T_84766_row0_col1, #T_84766_row0_col2, #T_84766_row1_col1, #T_84766_row1_col2, #T_84766_row2_col1, #T_84766_row2_col2, #T_84766_row2_col3, #T_84766_row3_col1, #T_84766_row3_col2, #T_84766_row4_col1, #T_84766_row4_col2, #T_84766_row4_col3, #T_84766_row5_col1, #T_84766_row5_col2, #T_84766_row5_col3, #T_84766_row6_col1, #T_84766_row6_col2, #T_84766_row6_col3, #T_84766_row7_col1, #T_84766_row7_col2, #T_84766_row7_col3, #T_84766_row8_col1, #T_84766_row8_col2, #T_84766_row8_col3, #T_84766_row9_col1, #T_84766_row9_col2, #T_84766_row10_col2, #T_84766_row11_col2, #T_84766_row12_col1, #T_84766_row12_col2, #T_84766_row12_col3, #T_84766_row13_col1, #T_84766_row13_col2, #T_84766_row14_col2, #T_84766_row14_col3, #T_84766_row15_col2, #T_84766_row15_col3, #T_84766_row16_col2, #T_84766_row16_col3, #T_84766_row17_col2, #T_84766_row17_col3, #T_84766_row18_col2, #T_84766_row18_col3, #T_84766_row19_col1, #T_84766_row19_col2, #T_84766_row19_col3, #T_84766_row20_col2, #T_84766_row20_col3 {
#   background-color: #cccccc;
#   color: #000000;
#   border: 1.3px dotted;
#   color: ;
#   caption-side: left;
# }
# #T_84766_row0_col3, #T_84766_row1_col3, #T_84766_row3_col3, #T_84766_row9_col3, #T_84766_row16_col1 {
#   background-color: #b3e2cd;
#   color: #000000;
#   border: 1.3px dotted;
#   color: ;
#   caption-side: left;
# }
# #T_84766_row10_col1 {
#   background-color: #fdcdac;
#   color: #000000;
#   border: 1.3px dotted;
#   color: ;
#   caption-side: left;
# }
# #T_84766_row10_col3, #T_84766_row11_col3, #T_84766_row13_col3, #T_84766_row15_col1 {
#   background-color: #f1e2cc;
#   color: #000000;
#   border: 1.3px dotted;
#   color: ;
#   caption-side: left;
# }
# #T_84766_row11_col1 {
#   background-color: #cbd5e8;
#   color: #000000;
#   border: 1.3px dotted;
#   color: ;
#   caption-side: left;
# }
# #T_84766_row14_col1, #T_84766_row18_col1 {
#   background-color: #fff2ae;
#   color: #000000;
#   border: 1.3px dotted;
#   color: ;
#   caption-side: left;
# }
# #T_84766_row17_col1, #T_84766_row20_col1 {
#   background-color: #f4cae4;
#   color: #000000;
#   border: 1.3px dotted;
#   color: ;
#   caption-side: left;
# }
# </style>
# <table id="T_84766">
#   <caption>**Summary of the product Data**</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_84766_level0_col0" class="col_heading level0 col0" >data type</th>
#       <th id="T_84766_level0_col1" class="col_heading level0 col1" >#missing</th>
#       <th id="T_84766_level0_col2" class="col_heading level0 col2" >Duplicate</th>
#       <th id="T_84766_level0_col3" class="col_heading level0 col3" >#unique</th>
#       <th id="T_84766_level0_col4" class="col_heading level0 col4" >min</th>
#       <th id="T_84766_level0_col5" class="col_heading level0 col5" >max</th>
#       <th id="T_84766_level0_col6" class="col_heading level0 col6" >avg</th>
#       <th id="T_84766_level0_col7" class="col_heading level0 col7" >std dev</th>
#       <th id="T_84766_level0_col8" class="col_heading level0 col8" >top value</th>
#       <th id="T_84766_level0_col9" class="col_heading level0 col9" >Freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84766_level0_row0" class="row_heading level0 row0" >NO</th>
#       <td id="T_84766_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_84766_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_84766_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_84766_row0_col3" class="data row0 col3" >104488</td>
#       <td id="T_84766_row0_col4" class="data row0 col4" >1.000000</td>
#       <td id="T_84766_row0_col5" class="data row0 col5" >104488.000000</td>
#       <td id="T_84766_row0_col6" class="data row0 col6" >52244.500000</td>
#       <td id="T_84766_row0_col7" class="data row0 col7" >30163.231801</td>
#       <td id="T_84766_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_84766_row0_col9" class="data row0 col9" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_84766_level0_row1" class="row_heading level0 row1" >ROWNUM</th>
#       <td id="T_84766_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_84766_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_84766_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_84766_row1_col3" class="data row1 col3" >104487</td>
#       <td id="T_84766_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_84766_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_84766_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_84766_row1_col7" class="data row1 col7" >nan</td>
#       <td id="T_84766_row1_col8" class="data row1 col8" >0:00</td>
#       <td id="T_84766_row1_col9" class="data row1 col9" >2</td>
#     </tr>
#     <tr>
#       <th id="T_84766_level0_row2" class="row_heading level0 row2" >totalCount</th>
#       <td id="T_84766_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_84766_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_84766_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_84766_row2_col3" class=

# %% [markdown]
# # 인사이트
# spec부분에 상세규격 별도기재 부분에 대한 해석을 논의해보아야함.
# 104488개 중에 101448개의 이름이 일치하지 않음. < 분류가 필요한 이유
# pdt_name에 brand 이름이 들어간 경우를 처리해야하는데 어떻게 할지. 우선 괄호를 다 지우고 단어들을 토큰화 시킬지.
#
# 전처리 목록 - 소문자 통일, 괄호,역슬래시 제거하고 공백 넣어서 토큰화 편리하게 만들기, 앞뒤 공백 제거,

# %%
# 원본 데이터는 df
df_test = df.copy()

import re

def preprocess_pdt_name(name):
    name = str(name).lower()  # object → 문자열 + 소문자
    # 괄호, 역슬래시, 슬래시 제거하고 위치에 공백 한 칸 추가
    name = re.sub(r'[()/\\]', ' ', name)
    # 연속된 공백을 하나로 통일
    name = re.sub(r'\s+', ' ', name)
    return name.strip()  # 앞뒤 공백 제거

# df_test에 적용
df_test['pdt_name'] = df_test['pdt_name'].apply(preprocess_pdt_name)

# 확인
print(df_test[['pdt_name']].head(10))
# Out:
#                         pdt_name
# 0                 전산기록지 80컬럼 양미싱
# 1                전산기록지 132컬럼 양미싱
# 2              팩스용지 15mx210mm 한솔
# 3              팩스용지 15mx216mm 한솔
# 4              팩스용지 30mx210mm 한솔
# 5              팩스용지 30mx216mm 한솔
# 6     복사용지a4 80g 더블에이 500매x5권 박스
# 7  컬러레이저용지a4 90g 500매 neusiedler
# 8  컬러레이저용지a3 90g 500매 neusiedler
# 9     복사용지b4 80g 더블에이 500매x5권 박스

# %%
# 공백 기준 토큰화
df_test['tokens'] = df_test['pdt_name'].apply(lambda x: x.split())

# 확인
print(df_test[['pdt_name','tokens']].head(10))
# Out:
#                         pdt_name                              tokens
# 0                 전산기록지 80컬럼 양미싱                  [전산기록지, 80컬럼, 양미싱]
# 1                전산기록지 132컬럼 양미싱                 [전산기록지, 132컬럼, 양미싱]
# 2              팩스용지 15mx210mm 한솔               [팩스용지, 15mx210mm, 한솔]
# 3              팩스용지 15mx216mm 한솔               [팩스용지, 15mx216mm, 한솔]
# 4              팩스용지 30mx210mm 한솔               [팩스용지, 30mx210mm, 한솔]
# 5              팩스용지 30mx216mm 한솔               [팩스용지, 30mx216mm, 한솔]
# 6     복사용지a4 80g 더블에이 500매x5권 박스    [복사용지a4, 80g, 더블에이, 500매x5권, 박스]
# 7  컬러레이저용지a4 90g 500매 neusiedler  [컬러레이저용지a4, 90g, 500매, neusiedler]
# 8  컬러레이저용지a3 90g 500매 neusiedler  [컬러레이저용지a3, 90g, 500매, neusiedler]
# 9     복사용지b4 80g 더블에이 500매x5권 박스    [복사용지b4, 80g, 더블에이, 500매x5권, 박스]

# %%
# 공백 기준 토큰화
df_test['tokens'] = df_test['pdt_name'].apply(lambda x: x.split())

# 확인
print(df_test[['pdt_name','tokens']].head(10))
# Out:
#                         pdt_name                              tokens
# 0                 전산기록지 80컬럼 양미싱                  [전산기록지, 80컬럼, 양미싱]
# 1                전산기록지 132컬럼 양미싱                 [전산기록지, 132컬럼, 양미싱]
# 2              팩스용지 15mx210mm 한솔               [팩스용지, 15mx210mm, 한솔]
# 3              팩스용지 15mx216mm 한솔               [팩스용지, 15mx216mm, 한솔]
# 4              팩스용지 30mx210mm 한솔               [팩스용지, 30mx210mm, 한솔]
# 5              팩스용지 30mx216mm 한솔               [팩스용지, 30mx216mm, 한솔]
# 6     복사용지a4 80g 더블에이 500매x5권 박스    [복사용지a4, 80g, 더블에이, 500매x5권, 박스]
# 7  컬러레이저용지a4 90g 500매 neusiedler  [컬러레이저용지a4, 90g, 500매, neusiedler]
# 8  컬러레이저용지a3 90g 500매 neusiedler  [컬러레이저용지a3, 90g, 500매, neusiedler]
# 9     복사용지b4 80g 더블에이 500매x5권 박스    [복사용지b4, 80g, 더블에이, 500매x5권, 박스]

# %%
import pandas as pd
import re
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
# 원본 데이터 df에서 테스트용 복사본 생성
df_test2 = df.copy()

def preprocess_pdt_name(name):
    name = str(name).lower()            # 소문자
    name = re.sub(r'[()/\\\[\]]', ' ', name)
  # 괄호, 슬래시, 역슬래시 제거 → 공백
    name = re.sub(r'\s+', ' ', name)    # 연속 공백을 한 칸으로
    return name.strip()                  # 앞뒤 공백 제거

df_test2['pdt_name_clean'] = df_test2['pdt_name'].apply(preprocess_pdt_name)

df_test2
# Out:
#             NO  ROWNUM totalCount  pdt_cd pdt_share pdt_share_txt send_chk  \
# 0            1  104488     104488  100001         Y            공유        Y
# 1            2  104487     104488  100002         Y            공유        Y
# 2            3  104486     104488  100003         Y            공유        Y
# 3            4  104485     104488  100004         Y            공유        Y
# 4            5  104484     104488  100005         Y            공유        Y
# ...        ...     ...        ...     ...       ...           ...      ...
# 104483  104484       5     104488  204575         Y            공유        Y
# 104484  104485       4     104488  204574         Y            공유        Y
# 104485  104486       3     104488  204585         Y            공유        Y
# 104486  104487       2     104488  204587         Y            공유        Y
# 104487  104488       1     104488  204586         Y            공유        Y
#
#        send_chk_txt pdt_code                             pdt_name  ...  \
# 0              전송완료       SO                      전산기록지(80컬럼/양미싱)  ...
# 1              전송완료       SO                     전산기록지(132컬럼/양미싱)  ...
# 2              전송완료       SO                   팩스용지(15mX210mm/한솔)  ...
# 3              전송완료       SO                   팩스용지(15mX216mm/한솔)  ...
# 4              전송완료       SO                   팩스용지(30mX210mm/한솔)  ...
# ...             ...      ...                                  ...  ...
# 104483         전송완료       SZ                     BKA-001 무릎 보호대 K  ...
# 104484         전송완료       SZ                       BKH-002 손목 보호대  ...
# 104485         전송완료       SZ  [고려에이스] Centrifuge Tube Rack 스텐원심관랙  ...
# 104486         전송완료       SZ                  Bambu 저온용 재사용 가능 스풀  ...
# 104487         전송완료       SZ                        [뱀부랩] PETG HF  ...
#
#        pdt_price pdt_request_date  pdt_simg_type           pdt_simg  \
# 0          25600          50:34.9              U                NaN
# 1          36100          50:34.9              U                NaN
# 2           2100          50:34.9              U                NaN
# 3           2100          50:34.9              U                NaN
# 4           3600          50:34.9              U                NaN
# ...          ...              ...            ...                ...
# 104483         0          25:45.8            NaN  cmarket_empty.png
# 104484         0          25:45.8            NaN  cmarket_empty.png
# 104485         0          31:18.6            NaN  cmarket_empty.png
# 104486         0          52:19.6            NaN  cmarket_empty.png
# 104487         0          52:19.6            NaN  cmarket_empty.png
#
#        pdt_simg_org pdt_simg_size brand_name dam_name pdt_simg_file_key  \
# 0               NaN           NaN      오피스디포      윤갑석               NaN
# 1               NaN           NaN      오피스디포      윤갑석               NaN
# 2               NaN           NaN      오피스디포      윤갑석               NaN
# 3               NaN           NaN      오피스디포      윤갑석               NaN
# 4               NaN           NaN      오피스디포      윤갑석               NaN
# ...             ...           ...        ...      ...               ...
# 104483          NaN           NaN        NaN      백제현               NaN
# 104484          NaN           NaN        NaN      백제현               NaN
# 104485          NaN           NaN      고려에이스      박예린               NaN
# 104486          NaN           NaN        뱀부랩      안재용               NaN
# 104487          NaN           NaN        뱀부랩      안재용               NaN
#
#                            pdt_name_clean
# 0                          전산기록지 80컬럼 양미싱
# 1                         전산기록지 132컬럼 양미싱
# 2                       팩스용지 15mx210mm 한솔
# 3                       팩스용지 15mx216mm 한솔
# 4                       팩스용지 30mx210mm 한솔
# ...                                   ...
# 104483                   bka-001 무릎 보호대 k
# 104484                     bkh-002 손목 보호대
# 104485  고려에이스 centrifuge tube rack 스텐원심관랙
# 104486                bambu 저온용 재사용 가능 스풀
# 104487                        뱀부랩 petg hf
#
# [104488 rows x 22 columns]

# %%
df_test2.columns
# Out:
# Index(['NO', 'ROWNUM', 'totalCount', 'pdt_cd', 'pdt_share', 'pdt_share_txt',
#        'send_chk', 'send_chk_txt', 'pdt_code', 'pdt_name', 'pdt_spec',
#        'pdt_cas', 'pdt_price', 'pdt_request_date', 'pdt_simg_type', 'pdt_simg',
#        'pdt_simg_org', 'pdt_simg_size', 'brand_name', 'dam_name',
#        'pdt_simg_file_key', 'pdt_name_clean'],
#       dtype='object')

# %%
df_new = df_test2[['pdt_name','pdt_name_clean','brand_name','pdt_price','pdt_cas']]

df_new['tokens'] = df_new['pdt_name_clean'].apply(lambda x: x.split()) # 토큰화
df_new['tokens_str'] = df_new['tokens'].apply(lambda x: ' '.join(x)) # 문자열 합침

# pdt_cas가 NaN인 행만 추출
df_nan_cas = df_new[df_new['pdt_cas'].isna()]

# 결과 확인
df_nan_cas
# pdt_cas 가 NaN인 것들을 뽑아내면 시약과 분리되어 데이터가 더 가벼워짐
# Out:
# /var/folders/vh/v6yfwz_x4xz31663ql80v00r0000gq/T/ipykernel_42311/2355649042.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['tokens'] = df_new['pdt_name_clean'].apply(lambda x: x.split()) # 토큰화
# /var/folders/vh/v6yfwz_x4xz31663ql80v00r0000gq/T/ipykernel_42311/2355649042.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['tokens_str'] = df_new['tokens'].apply(lambda x: ' '.join(x)) # 문자열 합침
#                                    pdt_name  \
# 0                           전산기록지(80컬럼/양미싱)
# 1                          전산기록지(132컬럼/양미싱)
# 2                        팩스용지(15mX210mm/한솔)
# 3                        팩스용지(15mX216mm/한솔)
# 4                        팩스용지(30mX210mm/한솔)
# ...                                     ...
# 104483                     BKA-001 무릎 보호대 K
# 104484                       BKH-002 손목 보호대
# 104485  [고려에이스] Centrifuge Tube Rack 스텐원심관랙
# 104486                  Bambu 저온용 재사용 가능 스풀
# 104487                        [뱀부랩] PETG HF
#
#                            pdt_name_clean brand_name  pdt_price pdt_cas  \
# 0                          전산기록지 80컬럼 양미싱      오피스디포      25600     NaN
# 1                         전산기록지 132컬럼 양미싱      오피스디포      36100     NaN
# 2                       팩스용지 15mx210mm 한솔      오피스디포       2100     NaN
# 3                       팩스용지 15mx216mm 한솔      오피스디포       2100     NaN
# 4                       팩스용지 30mx210mm 한솔      오피스디포       3600     NaN
# ...                                   ...        ...        ...     ...
# 104483                   bka-001 무릎 보호대 k        NaN          0     NaN
# 104484                     bkh-002 손목 보호대        NaN          0     NaN
# 104485  고려에이스 centrifuge tube rack 스텐원심관랙      고려에이스          0     NaN
# 104486                bambu 저온용 재사용 가능 스풀        뱀부랩          0     NaN
# 104487                        뱀부랩 petg hf        뱀부랩          0     NaN
#
#                                          tokens  \
# 0                            [전산기록지, 80컬럼, 양미싱]
# 1                           [전산기록지, 132컬럼, 양미싱]
# 2                         [팩스용지, 15mx210mm, 한솔]
# 3                         [팩스용지, 15mx216mm, 한솔]
# 4                         [팩스용지, 30mx210mm, 한솔]
# ...                                         ...
# 104483                    [bka-001, 무릎, 보호대, k]
# 104484                       [bkh-002, 손목, 보호대]
# 104485  [고려에이스, centrifuge, tube, rack, 스텐원심관랙]
# 104486                [bambu, 저온용, 재사용, 가능, 스풀]
# 104487                          [뱀부랩, petg, hf]
#
#                                tokens_str
# 0                          전산기록지 80컬럼 양미싱
# 1                         전산기록지 132컬럼 양미싱
# 2                       팩스용지 15mx210mm 한솔
# 3                       팩스용지 15mx216mm 한솔
# 4                       팩스용지 30mx210mm 한솔
# ...                                   ...
# 104483                   bka-001 무릎 보호대 k
# 104484                     bkh-002 손목 보호대
# 104485  고려에이스 centrifuge tube rack 스텐원심관랙
# 104486                bambu 저온용 재사용 가능 스풀
# 104487                        뱀부랩 petg hf
#
# [63934 rows x 7 columns]

# %%
# minibatchkmeans로 1차 그루핑 + dbscan으로 2차 그루핑 하는 방법

# import pandas as pd
# import numpy as np
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.cluster import MiniBatchKMeans, DBSCAN

# # 데이터 준비
# df_cluster = df.copy()  # 원본 영향 안 주기
# df_cluster['pdt_name_clean'] = df_cluster['pdt_name'].str.lower()  # 소문자
# df_cluster['pdt_name_clean'] = df_cluster['pdt_name_clean'].str.replace(r'[()\[\]/\\]', ' ', regex=True)  # 괄호/슬래시 제거
# df_cluster['pdt_name_clean'] = df_cluster['pdt_name_clean'].str.replace(r'\s+', ' ', regex=True).str.strip()  # 공백 정리

# # pdt_name_clean 컬럼 결측값 처리
# df_new['pdt_name_clean'] = df_new['pdt_name_clean'].fillna('')

# # TF-IDF 벡터화
# vectorizer = TfidfVectorizer(analyzer='word')
# X = vectorizer.fit_transform(df_new['pdt_name_clean'])


# # MiniBatchKMeans로 1차 그룹
# n_clusters = 3000  # 거칠게 쪼개는 수준
# kmeans = MiniBatchKMeans(n_clusters=n_clusters, random_state=42, batch_size=1000)
# df_cluster['kmeans_group'] = kmeans.fit_predict(X)

# # DBSCAN 2차 그룹 (각 KMeans 그룹 내) 세밀하게
# final_groups = np.zeros(len(df_cluster), dtype=int)
# current_label = 0

# for grp in df_cluster['kmeans_group'].unique():
#     idx = df_cluster.index[df_cluster['kmeans_group'] == grp]
#     X_sub = X[idx]
    
#     # DBSCAN 적용
#     db = DBSCAN(eps=0.3, min_samples=2, metric='cosine')
#     labels_sub = db.fit_predict(X_sub)
    
#     # -1 (noise) 제외하고, 전체 레이블 offset
#     labels_sub = np.where(labels_sub == -1, -1, labels_sub + current_label)
    
#     final_groups[idx] = labels_sub.max() if labels_sub.max() > 0 else current_label

# df_cluster['final_group'] = final_groups

# #결과 확인
# print(df_cluster[['pdt_name', 'pdt_name_clean', 'kmeans_group', 'final_group']].head(20))

# %%
# gpt 코드 개선 2 노이즈 추가 버전
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
import hdbscan

# 원본 영향 없이 처리
df_cluster1 = df_nan_cas.copy()

# 1️⃣ 제품명 전처리
df_cluster1 = df_cluster1.reset_index(drop=True)
df_cluster1['pdt_name_clean'] = df_cluster1['pdt_name_clean'].fillna('')

# 2️⃣ SentenceTransformer 임베딩 (batch 처리)
model = SentenceTransformer('all-MiniLM-L6-v2')
batch_size = 1024
embeddings = []

for i in range(0, len(df_cluster1), batch_size):
    batch_texts = df_cluster1['pdt_name_clean'].iloc[i:i+batch_size].tolist()
    batch_emb = model.encode(batch_texts)
    embeddings.append(batch_emb)

embeddings = np.vstack(embeddings)

# 3️⃣ HDBSCAN 군집화
clusterer = hdbscan.HDBSCAN(
    min_cluster_size=5,
    min_samples=2,
    metric='euclidean',
    cluster_selection_method='eom'
)

cluster_labels = clusterer.fit_predict(embeddings)
df_cluster1['group_id'] = cluster_labels

# 4️⃣ 노이즈(-1) 처리: 가장 가까운 클러스터에 합치기
unique_clusters = [c for c in np.unique(cluster_labels) if c != -1]
cluster_centers = {}

for c in unique_clusters:
    idx = np.where(cluster_labels == c)[0]
    cluster_centers[c] = embeddings[idx].mean(axis=0)

for i, label in enumerate(cluster_labels):
    if label == -1:
        # 노이즈 제품
        distances = [np.linalg.norm(embeddings[i] - cluster_centers[c]) for c in unique_clusters]
        nearest_cluster = unique_clusters[np.argmin(distances)]
        df_cluster1.at[i, 'group_id'] = nearest_cluster

# 5️⃣ 각 클러스터 대표 제품 선정
representatives = []
for grp in df_cluster1['group_id'].unique():
    idx = np.where(df_cluster1['group_id'] == grp)[0]
    group_embeddings = embeddings[idx]
    center = group_embeddings.mean(axis=0)
    distances = np.linalg.norm(group_embeddings - center, axis=1)
    rep_idx = idx[np.argmin(distances)]
    representatives.append((grp, df_cluster1.iloc[rep_idx]['pdt_name']))

df_representatives = pd.DataFrame(representatives, columns=['group_id', '대표_제품'])

# 6️⃣ 결과 확인
print(df_cluster1[['pdt_name', 'pdt_name_clean', 'group_id']].head(20))
print(df_representatives.head(20))

# 7️⃣ CSV 저장
# df_cluster1.to_csv('df_cluster1_final.csv', index=False)

# %%
# print(len(df_cluster1), embeddings.shape[0]) # df_new와 섞여서 값이 튀었던 것 같음. 제거 이후 다시 코드 돌리니 같은 값이 나오는 것을 확인.

# %%
ct_data = pd.read_csv('/Users/c-market/Downloads/df_cluster1.csv')
ct_data
# Out:
#                                   pdt_name                     pdt_name_clean  \
# 0                          전산기록지(80컬럼/양미싱)                     전산기록지 80컬럼 양미싱
# 1                         전산기록지(132컬럼/양미싱)                    전산기록지 132컬럼 양미싱
# 2                       팩스용지(15mX210mm/한솔)                  팩스용지 15mx210mm 한솔
# 3                       팩스용지(15mX216mm/한솔)                  팩스용지 15mx216mm 한솔
# 4                       팩스용지(30mX210mm/한솔)                  팩스용지 30mx210mm 한솔
# ...                                    ...                                ...
# 63929                     BKA-001 무릎 보호대 K                   bka-001 무릎 보호대 k
# 63930                       BKH-002 손목 보호대                     bkh-002 손목 보호대
# 63931  [고려에이스] Centrifuge Tube Rack 스텐원심관랙  고려에이스 centrifuge tube rack 스텐원심관랙
# 63932                  Bambu 저온용 재사용 가능 스풀                bambu 저온용 재사용 가능 스풀
# 63933                        [뱀부랩] PETG HF                        뱀부랩 petg hf
#
#       brand_name  pdt_price  pdt_cas  \
# 0          오피스디포      25600      NaN
# 1          오피스디포      36100      NaN
# 2          오피스디포       2100      NaN
# 3          오피스디포       2100      NaN
# 4          오피스디포       3600      NaN
# ...          ...        ...      ...
# 63929        NaN          0      NaN
# 63930        NaN          0      NaN
# 63931      고려에이스          0      NaN
# 63932        뱀부랩          0      NaN
# 63933        뱀부랩          0      NaN
#
#                                                   tokens  \
# 0                               ['전산기록지', '80컬럼', '양미싱']
# 1                              ['전산기록지', '132컬럼', '양미싱']
# 2                            ['팩스용지', '15mx210mm', '한솔']
# 3                            ['팩스용지', '15mx216mm', '한솔']
# 4                            ['팩스용지', '30mx210mm', '한솔']
# ...                                                  ...
# 63929                      ['bka-001', '무릎', '보호대', 'k']
# 63930                           ['bkh-002', '손목', '보호대']
# 63931  ['고려에이스', 'centrifuge', 'tube', 'rack', '스텐원심관랙']
# 63932                ['bambu', '저온용', '재사용', '가능', '스풀']
# 63933                              ['뱀부랩', 'petg', 'hf']
#
#                               tokens_str  group_id
# 0                         전산기록지 80컬럼 양미싱      2337
# 1                        전산기록지 132컬럼 양미싱      2365
# 2                      팩스용지 15mx210mm 한솔      1988
# 3                      팩스용지 15mx216mm 한솔      1988
# 4                      팩스용지 30mx210mm 한솔      1987
# ...                                  ...       ...
# 63929                   bka-001 무릎 보호대 k      1165
# 63930                     bkh-002 손목 보호대      1545
# 63931  고려에이스 centrifuge tube rack 스텐원심관랙       871
# 63932                bambu 저온용 재사용 가능 스풀      1012
# 63933                        뱀부랩 petg hf      1627
#
# [63934 rows x 8 columns]

# %% [markdown]
# ### 그룹핑 된 아이템들을 확인한 결과 머신러닝을 기반으로 진행했을 때 완벽히 일치하는 제품들로 뽑아내기 어려움 선제적인 전처리 or 이후 분류할 수 있는 방법이 있으면 좋지 않을까
